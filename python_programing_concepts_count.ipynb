# %% [markdown]
# <a href="https://colab.research.google.com/github/LavanyaNadigottu/python-programing/blob/main/python_programing_concepts_count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# prompt: import basic pandas library and read the file /content/Salaries.csv

import pandas as pd
df = pd.read_csv('/content/Salaries.csv')
df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# prompt: import basic pandas library and use pandas library to read the file /content/Salaries.csv

# No additional code needed as the provided code already imports pandas and reads the file.
# The type(df) line confirms the correct data type (pandas DataFrame).

# %%
# prompt: import basic pandas library and read the file using the pandas library /content/Salaries.csv

import pandas as pd
df = pd.read_csv('/content/Salaries.csv')
df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
# prompt: can you use head function on df data frame

df.head(10) #show the first 10 rows
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
# prompt: can you use head function on df data frame and show me the first 10 records

df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
# prompt: can you use the tail function and show me the last 10 records in df data frame

df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
# prompt: can you tell me about the data types for columns in data frame df

df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
# prompt: can you tell me what are the column names in dataframe df

df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.shape
# Out:
# (78, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
# prompt: check for null values in dataframe df

df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
# prompt: check for null values in dataframe df, can you also confirm if there are any null values in our data set

df.isnull().values.any()
# Out:
# False

# %%
df.isnull().any()
# Out:
# rank          False
# discipline    False
# phd           False
# service       False
# sex           False
# salary        False
# dtype: bool

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
# prompt: can you find out the mean for salary column

df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427904

# %%
df['salary'].std()
# Out:
# 28293.661022264165

# %%
# prompt: can you find out basic stats information on my dataframe df, calculate measurements such as mean, median, mode, variance, std, range, skewness, kurtosis

import pandas as pd
from scipy.stats import skew, kurtosis

# Assuming 'df' is your DataFrame and 'salary' is the column you want to analyze
# If your column name is different replace 'salary' with your column name

# Mean
mean_salary = df['salary'].mean()
print("Mean:", mean_salary)

# Median
median_salary = df['salary'].median()
print("Median:", median_salary)

# Mode
mode_salary = df['salary'].mode()  #access the first mode if multipal exists
print("Mode:", mode_salary)

# Variance
variance_salary = df['salary'].var()
print("Variance:", variance_salary)

# Standard Deviation
std_salary = df['salary'].std()
print("Standard Deviation:", std_salary)

# Range
range_salary = df['salary'].max() - df['salary'].min() #range=max-min
print("Range:", range_salary)

# Skewness
skewness_salary = skew(df['salary'])
print("Skewness:", skewness_salary)

# Kurtosis
kurtosis_salary = kurtosis(df['salary'])
print("Kurtosis:", kurtosis_salary)
# Out:
# Mean: 108023.78205128205
# Median: 104671.0
# Mode: 0    92000
# Name: salary, dtype: int64
# Variance: 800531254.0427904
# Standard Deviation: 28293.661022264165
# Range: 129160
# Skewness: 0.443361422461378
# Kurtosis: -0.4523692672246771

# %%
df[df['salary']>50000]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[:,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[:10,:]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.mean(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-40dc65ed7e52> in <cell line: 1>()
# ----> 1 df.mean(numeric_only=True)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df=pd.read_csv('Salaries.csv')

# %%
df.mean(numeric_only=True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.groupby('rank').mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby('rank')[['salary','service','phd']].mean()
# Out:
#                   salary    service        phd
# rank
# AssocProf   91786.230769  11.307692  15.076923
# AsstProf    81362.789474   2.210526   5.052632
# Prof       123624.804348  21.413043  27.065217

# %%
df.groupby('rank')[['salary','service','phd']].mean(numeric_only=True)
# Out:
#                   salary    service        phd
# rank
# AssocProf   91786.230769  11.307692  15.076923
# AsstProf    81362.789474   2.210526   5.052632
# Prof       123624.804348  21.413043  27.065217

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 df1=pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df1['SAT']) #The error message TypeError: 'DataFrame' object is not callable indicates that you are trying to call the DataFrame df1 as a function using parentheses df1('SAT'). DataFrames are not callable, and you should use square brackets df1['SAT'] to access a column.
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df1['SAT'])#Use square brackets to access the 'SAT' column of the DataFrame and parentheses to call the hist function.
plt.show() #if u dont want intervals

# %%
plt.hist(df1['SAT'])      # v cn give a labels, matplotib library has hist attribute
plt.xlabel('SAT Scores')
plt.ylabel('Frequency')
plt.title('Distribution of SAT Scores')
plt.show()

# %%
# prompt: can you create a histogram on sat score column in the dataframe df1

plt.hist(df1['SAT'], bins=10)  # Use bins to specify the number of intervals
plt.xlabel('SAT Scores')
plt.ylabel('Frequency')
plt.title('Distribution of SAT Scores')
plt.show()

# %%
sns.histplot(df1['SAT']) #seaborn library has histplot attribute
# Out:
# <Axes: xlabel='SAT', ylabel='Count'>

# %%
sns.histplot(df1['Accept'])
plt.show()

# %%
plt.plot(df1['Accept'],df1['SAT'])

# %%
plt.plot(df1['Accept'],df1['SAT'],'bo')#bo=blue col,go=green col, r+=+

# %%
plt.plot(df1['Accept'],df1['SAT'],'bo')
plt.xlabel('Accept')
plt.ylabel('SAT')
plt.title('Scatter Plot of Accept vs SAT')
plt.show()

# %%
# prompt: can you create a scatter plot between accept column and sat column in dataframe df1

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.scatter(df1['Accept'], df1['SAT'])
plt.xlabel('Accept')
plt.ylabel('SAT')
plt.title('Scatter Plot of Accept vs SAT')
plt.grid(True)  # Add a grid for better readability
plt.show()

# %%
# prompt: can you create a scatter plot between accept column and sat column in dataframe df1, now can you add red color markers

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.scatter(df1['Accept'], df1['SAT'], color='red') # Set the color to red
plt.xlabel('Accept')
plt.ylabel('SAT')
plt.title('Scatter Plot of Accept vs SAT')
plt.grid(True)  # Add a grid for better readability
plt.show()

# %%
help(plt.plot) #if u get any error then it will helps you
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
sns.pairplot(df1) #v cn create pairplot is combition of histogram nd scatter plot

# %%
sns.pairplot(df1.iloc[:,1:3])#using iloc function sellect all the rows and i want to create my pair plot only for column1 and column2

# %%
import warnings                        # for ignoring warnings
warnings.filterwarnings('ignore')
sns.distplot(df1['Accept'])
plt.show()

# %%
# prompt: can you create distplot for all the columns in dataframe df1

import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df1 is your DataFrame
for col in df1.columns:
    if df1[col].dtype in ['int64', 'float64']:  # Check for numeric columns
        plt.figure(figsize=(8, 6))  # Adjust figure size as needed
        sns.distplot(df1[col])
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Frequency')
        plt.show()

# %%
plt.boxplot(df1['Accept'])
plt.show()

# %%
# prompt: can you write a narrative summary on the box plot of accept column in dataframe df1

# Assuming the boxplot of 'Accept' column in df1 has already been generated using:
# plt.boxplot(df1['Accept'])
# plt.show()

# Narrative Summary of the Box Plot:

# The box plot of the 'Accept' column in the df1 DataFrame visualizes the distribution of university acceptance rates.
# The box represents the interquartile range (IQR), spanning from the 25th percentile (Q1) to the 75th percentile (Q3) of the acceptance rates.
# The line within the box indicates the median acceptance rate.  The whiskers extend to 1.5 times the IQR from the edges of the box, capturing the majority of the data points.
# Any points beyond the whiskers are considered outliers and are plotted individually.

# Based on the box plot (which you have generated), you can describe the distribution:
#  * Is the distribution symmetric or skewed? (If the median line is in the center of the box, it's more symmetric. If it's closer to one end, it's skewed.)
#  * Are there many outliers?  (A large number of points beyond the whiskers indicates a high number of extreme acceptance rates.)
#  * What is the approximate range of the data? (You can estimate the minimum and maximum acceptance rates by looking at the ends of the whiskers and the individual outliers.)
#  * What is the median acceptance rate? (The line inside the box indicates this.)

# Example:
# "The box plot of acceptance rates shows a slightly right-skewed distribution. The median acceptance rate is approximately [median value].  There are a few outlier universities with exceptionally low acceptance rates."

# You need to observe your generated plot to fill in the specific details.

# %%
# prompt: can you create a box plot on accept column in dataframe df1

import matplotlib.pyplot as plt

plt.boxplot(df1['Accept'])
plt.title('Box Plot of Accept') #Added a title
plt.xlabel('Accept') #added a x-axis label
plt.ylabel('Values') #Added a y-axis label
plt.show()

# %%
import numpy as np #it is used for creating array #more convinient for machine learning

# %%
a=np.array([1,2,3,4])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (4,)

# %%
a.size
# Out:
# 4

# %%
a.sum()
# Out:
# 10

# %%
# prompt: can you calculate the sum of a

import numpy as np

a = np.array([1, 2, 3, 4])
print(a.sum())
# Out:
# 10

# %%
a.prod()
# Out:
# 24

# %%
a.min()
# Out:
# 1

# %%
a.max()
# Out:
# 4

# %%
a.min()-a.max()
# Out:
# -3

# %%
b=np.array([(1,2,3,4),(4,5,6,7)])

# %%
b
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
b.shape
# Out:
# (2, 4)

# %%
b.size
# Out:
# 8

# %%
b=b.reshape(4,2)    #() function #[] access the element,columns,rows

# %%
b
# Out:
# array([[1, 2],
#        [3, 4],
#        [4, 5],
#        [6, 7]])

# %%
b[0]
# Out:
# array([1, 2])

# %%
b[0,0]
# Out:
# 1

# %%
b[0,1]
# Out:
# 2

# %%
b.sum(axis=0)
# Out:
# array([14, 18])

# %%
b.sum(axis=1)
# Out:
# array([ 3,  7,  9, 13])
